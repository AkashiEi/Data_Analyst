# %% [markdown]
# # 个人Pandas常用功能合集~持续更新（大概）

# %% [markdown]
# ## 可能有点乱，大部分属于想到什么就写什么

# %% [markdown]
# ###  **导入依赖库**

# %%
import pandas as pd

# %% [markdown]
# ##### 关掉warning

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### **读取数据**
# #### **读取csv、txt文件**
# `pd.read_csv(文件名, sep=·分隔符，默认是','·, header=·第几行开始读取，默认0·,encoding=·编码格式，默认utf8·)
# `
# #### **读取xls、xlsx文件**
# `pd.read_excel(文件名, sheet_name=·sheet名/序号（从0开始），默认第一个，若填写None时会全读取,，但返回的将是字典格式·)
# `

# %%
df0 = pd.read_excel('Desktop/test_data.xlsx',sheet_name='主机游戏')
df0
# Out:
#           游戏名  游玩时长(h)       发布时间
# 0  塞〇达传说 旷野之息      600 2017-03-03
# 1      马〇奥赛车8       60 2017-12-15
# 2       宝〇梦·剑      300 2019-11-15
# 3       宝〇梦·盾      700 2019-11-15
# 4  塞〇达传说 旷野之息      600 2017-03-03
# 5     十〇机兵防卫圈      100 2020-03-19
# 6      〇之轨迹IV       70 2018-09-27

# %%
df1 = pd.read_excel('Desktop/test_data.xlsx',sheet_name=1)
df1
# Out:
#                    游戏名  游玩时长(h)       发布时间
# 0     Fate/G〇and Order    900.0 2015-08-12
# 1                 明日〇舟    500.0 2019-05-01
# 2  世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20
# 3                 碧蓝〇线     90.0 2017-06-02
# 4          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09
# 5          公主〇结re:dive    700.0 2018-02-15

# %%
pd.read_excel('Desktop/test_data.xlsx',sheet_name=None)
# Out:
# {'主机游戏':           游戏名  游玩时长(h)       发布时间
#  0  塞〇达传说 旷野之息      600 2017-03-03
#  1      马〇奥赛车8       60 2017-12-15
#  2       宝〇梦·剑      300 2019-11-15
#  3       宝〇梦·盾      700 2019-11-15
#  4  塞〇达传说 旷野之息      600 2017-03-03
#  5     十〇机兵防卫圈      100 2020-03-19
#  6      〇之轨迹IV       70 2018-09-27,
#  '手机游戏':                    游戏名  游玩时长(h)       发布时间
#  0     Fate/G〇and Order    900.0 2015-08-12
#  1                 明日〇舟    500.0 2019-05-01
#  2  世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20
#  3                 碧蓝〇线     90.0 2017-06-02
#  4          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09
#  5          公主〇结re:dive    700.0 2018-02-15,
#  'PC游戏':                   游戏名  游玩时长(h)       发布时间
#  0  Grand 〇heft Auto V      700 2013-09-17
#  1           mine〇raft     2000 2011-11-18
#  2              植物大战僵〇      900 2009-05-05
#  3               魔法〇之夜       90 2012-04-12}

# %% [markdown]
# ### 保存数据
# `df.to_excel(path,index={False,True})`
# 不演示了，自行动手吧~

# %% [markdown]
# ### **数据处理**
# #### **拼接**
# 每一个sheet/文件内的格式是一致时可以用Concat方式将两个文档内的内容合并
# `pd.concat([df1,df2,...],axis=·默认0，0为纵向拼接，1为横向拼接·,ignore_index=·默认False，False为不重置index,纵向拼接时最后重置·)`

# %%
pd.concat([df0,df1],axis=1)
# Out:
#           游戏名  游玩时长(h)       发布时间                  游戏名  游玩时长(h)       发布时间
# 0  塞〇达传说 旷野之息      600 2017-03-03     Fate/G〇and Order    900.0 2015-08-12
# 1      马〇奥赛车8       60 2017-12-15                 明日〇舟    500.0 2019-05-01
# 2       宝〇梦·剑      300 2019-11-15  世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20
# 3       宝〇梦·盾      700 2019-11-15                 碧蓝〇线     90.0 2017-06-02
# 4  塞〇达传说 旷野之息      600 2017-03-03          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09
# 5     十〇机兵防卫圈      100 2020-03-19          公主〇结re:dive    700.0 2018-02-15
# 6      〇之轨迹IV       70 2018-09-27                  NaN      NaN        NaT

# %%
pd.concat([df0,df1])
# Out:
#                    游戏名  游玩时长(h)       发布时间
# 0           塞〇达传说 旷野之息    600.0 2017-03-03
# 1               马〇奥赛车8     60.0 2017-12-15
# 2                宝〇梦·剑    300.0 2019-11-15
# 3                宝〇梦·盾    700.0 2019-11-15
# 4           塞〇达传说 旷野之息    600.0 2017-03-03
# 5              十〇机兵防卫圈    100.0 2020-03-19
# 6               〇之轨迹IV     70.0 2018-09-27
# 0     Fate/G〇and Order    900.0 2015-08-12
# 1                 明日〇舟    500.0 2019-05-01
# 2  世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20
# 3                 碧蓝〇线     90.0 2017-06-02
# 4          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09
# 5          公主〇结re:dive    700.0 2018-02-15

# %%
df2 = pd.concat([df0,df1],ignore_index=True)
df2
# Out:
#                     游戏名  游玩时长(h)       发布时间
# 0            塞〇达传说 旷野之息    600.0 2017-03-03
# 1                马〇奥赛车8     60.0 2017-12-15
# 2                 宝〇梦·剑    300.0 2019-11-15
# 3                 宝〇梦·盾    700.0 2019-11-15
# 4            塞〇达传说 旷野之息    600.0 2017-03-03
# 5               十〇机兵防卫圈    100.0 2020-03-19
# 6                〇之轨迹IV     70.0 2018-09-27
# 7      Fate/G〇and Order    900.0 2015-08-12
# 8                  明日〇舟    500.0 2019-05-01
# 9   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20
# 10                 碧蓝〇线     90.0 2017-06-02
# 11          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09
# 12          公主〇结re:dive    700.0 2018-02-15

# %% [markdown]
# #### 在不知道有多少sheet的同时并增加sheet名

# %%
sheet_name_list = list(pd.read_excel('Desktop/test_data.xlsx',sheet_name=None).keys())
df0=[]
for i in sheet_name_list:
    df1 = pd.read_excel('Desktop/test_data.xlsx',sheet_name=i)
    df1['游戏平台'] = i
    df0.append(df1)
df2 = pd.concat(df0,ignore_index=True)
df2
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏
# 4            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏
# 5               十〇机兵防卫圈    100.0 2020-03-19  主机游戏
# 6                〇之轨迹IV     70.0 2018-09-27  主机游戏
# 7      Fate/G〇and Order    900.0 2015-08-12  手机游戏
# 8                  明日〇舟    500.0 2019-05-01  手机游戏
# 9   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏
# 10                 碧蓝〇线     90.0 2017-06-02  手机游戏
# 11          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09  手机游戏
# 12          公主〇结re:dive    700.0 2018-02-15  手机游戏
# 13   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏
# 14            mine〇raft   2000.0 2011-11-18  PC游戏
# 15               植物大战僵〇    900.0 2009-05-05  PC游戏
# 16                魔法〇之夜     90.0 2012-04-12  PC游戏

# %% [markdown]
# #### **去重**
# `df.drop_duplicates(subset=·默认None，指全部·, keep={'first'，'last'},inplace=·默认False，指直接覆盖·, ignore_index=False)`

# %%
df2.drop_duplicates()
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏
# 5               十〇机兵防卫圈    100.0 2020-03-19  主机游戏
# 6                〇之轨迹IV     70.0 2018-09-27  主机游戏
# 7      Fate/G〇and Order    900.0 2015-08-12  手机游戏
# 8                  明日〇舟    500.0 2019-05-01  手机游戏
# 9   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏
# 10                 碧蓝〇线     90.0 2017-06-02  手机游戏
# 11          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09  手机游戏
# 12          公主〇结re:dive    700.0 2018-02-15  手机游戏
# 13   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏
# 14            mine〇raft   2000.0 2011-11-18  PC游戏
# 15               植物大战僵〇    900.0 2009-05-05  PC游戏
# 16                魔法〇之夜     90.0 2012-04-12  PC游戏

# %%
df2.drop_duplicates(keep='last')
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏
# 4            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏
# 5               十〇机兵防卫圈    100.0 2020-03-19  主机游戏
# 6                〇之轨迹IV     70.0 2018-09-27  主机游戏
# 7      Fate/G〇and Order    900.0 2015-08-12  手机游戏
# 8                  明日〇舟    500.0 2019-05-01  手机游戏
# 9   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏
# 10                 碧蓝〇线     90.0 2017-06-02  手机游戏
# 11          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09  手机游戏
# 12          公主〇结re:dive    700.0 2018-02-15  手机游戏
# 13   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏
# 14            mine〇raft   2000.0 2011-11-18  PC游戏
# 15               植物大战僵〇    900.0 2009-05-05  PC游戏
# 16                魔法〇之夜     90.0 2012-04-12  PC游戏

# %%
df3 = df2.drop_duplicates(ignore_index=True)
df3
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏
# 7                  明日〇舟    500.0 2019-05-01  手机游戏
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏
# 10          刀剑〇域黑衣剑士：王牌      NaN 2021-06-09  手机游戏
# 11          公主〇结re:dive    700.0 2018-02-15  手机游戏
# 12   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏
# 13            mine〇raft   2000.0 2011-11-18  PC游戏
# 14               植物大战僵〇    900.0 2009-05-05  PC游戏
# 15                魔法〇之夜     90.0 2012-04-12  PC游戏

# %% [markdown]
# #### **空值填充**
# `df.fillna(value=None, method={‘backfill’, ‘bfill’, ‘pad’, ‘ffill’, None})`

# %%
df3.fillna('无游玩时间')
# Out:
#                     游戏名 游玩时长(h)       发布时间  游戏平台
# 0            塞〇达传说 旷野之息     600 2017-03-03  主机游戏
# 1                马〇奥赛车8      60 2017-12-15  主机游戏
# 2                 宝〇梦·剑     300 2019-11-15  主机游戏
# 3                 宝〇梦·盾     700 2019-11-15  主机游戏
# 4               十〇机兵防卫圈     100 2020-03-19  主机游戏
# 5                〇之轨迹IV      70 2018-09-27  主机游戏
# 6      Fate/G〇and Order     900 2015-08-12  手机游戏
# 7                  明日〇舟     500 2019-05-01  手机游戏
# 8   世界计〇彩色舞台 feat. 初音未来     100 2020-09-20  手机游戏
# 9                  碧蓝〇线      90 2017-06-02  手机游戏
# 10          刀剑〇域黑衣剑士：王牌   无游玩时间 2021-06-09  手机游戏
# 11          公主〇结re:dive     700 2018-02-15  手机游戏
# 12   Grand 〇heft Auto V     700 2013-09-17  PC游戏
# 13            mine〇raft    2000 2011-11-18  PC游戏
# 14               植物大战僵〇     900 2009-05-05  PC游戏
# 15                魔法〇之夜      90 2012-04-12  PC游戏

# %%
df3.fillna(0)
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏
# 7                  明日〇舟    500.0 2019-05-01  手机游戏
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏
# 10          刀剑〇域黑衣剑士：王牌      0.0 2021-06-09  手机游戏
# 11          公主〇结re:dive    700.0 2018-02-15  手机游戏
# 12   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏
# 13            mine〇raft   2000.0 2011-11-18  PC游戏
# 14               植物大战僵〇    900.0 2009-05-05  PC游戏
# 15                魔法〇之夜     90.0 2012-04-12  PC游戏

# %% [markdown]
# #### **空值合计**
# `df.isnull().sum()`

# %%
df3.isnull().sum()
# Out:
# 游戏名        0
# 游玩时长(h)    1
# 发布时间       0
# 游戏平台       0
# dtype: int64

# %% [markdown]
# #### **去除空值**
# `df.dropna(axis=0,inplace=False)`

# %%
df4 = df3.dropna()
df4
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏
# 7                  明日〇舟    500.0 2019-05-01  手机游戏
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏
# 11          公主〇结re:dive    700.0 2018-02-15  手机游戏
# 12   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏
# 13            mine〇raft   2000.0 2011-11-18  PC游戏
# 14               植物大战僵〇    900.0 2009-05-05  PC游戏
# 15                魔法〇之夜     90.0 2012-04-12  PC游戏

# %% [markdown]
# #### lambda处理
# `df.apply(lambda x: fun(),axis={0,1})`

# %%
df4['Month'] = df4['发布时间'].apply(lambda x: str(x.month)+'月')
df4
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏   11月
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏   11月
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏    3月
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏    9月
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月
# 7                  明日〇舟    500.0 2019-05-01  手机游戏    5月
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏    6月
# 11          公主〇结re:dive    700.0 2018-02-15  手机游戏    2月
# 12   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏    9月
# 13            mine〇raft   2000.0 2011-11-18  PC游戏   11月
# 14               植物大战僵〇    900.0 2009-05-05  PC游戏    5月
# 15                魔法〇之夜     90.0 2012-04-12  PC游戏    4月

# %%
def get_year_month(x):
    y = str(x['发布时间'].year) + '年' + str(x['发布时间'].month) + '月'
    return y

# %%
df4['年月'] = df4.apply(lambda x : get_year_month(x),axis=1)
df4
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏    3月   2020年3月
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏    9月   2018年9月
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月
# 7                  明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月   2020年9月
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏    6月   2017年6月
# 11          公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月
# 12   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏    9月   2013年9月
# 13            mine〇raft   2000.0 2011-11-18  PC游戏   11月  2011年11月
# ...

# %% [markdown]
# ### 数据统计
# #### 最大值、最小值、平均值、计数
# `df.max()
# df.min()
# df.mean()
# df.count()`

# %%
df4['游玩时长(h)'].max()
# Out:
# 2000.0

# %%
df4['游玩时长(h)'].min()
# Out:
# 60.0

# %%
df4['游玩时长(h)'].mean()
# Out:
# 520.6666666666666

# %%
df4.count()
# Out:
# 游戏名        15
# 游玩时长(h)    15
# 发布时间       15
# 游戏平台       15
# Month      15
# 年月         15
# dtype: int64

# %% [markdown]
# ##### 手机游戏的平均游玩时长

# %%
df4[df4['游戏平台'] == '手机游戏']['游玩时长(h)'].mean()
# Out:
# 458.0

# %% [markdown]
# ##### 主机游戏游玩时长最长的游戏

# %%
#先得到最大值
zhuji = df4[df4['游戏平台'] == '主机游戏']['游玩时长(h)'].max()

df4[(df4['游玩时长(h)'] == zhuji)&(df4['游戏平台'] == '主机游戏')]
# Out:
#      游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月
# 3  宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月

# %% [markdown]
# #### describe方法
# `df.describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False)`

# %% [markdown]
# ##### 默认的话是会出现连续性数据

# %%
df4.describe()
# Out:
#            游玩时长(h)
# count    15.000000
# mean    520.666667
# std     518.809994
# min      60.000000
# 25%      95.000000
# 50%     500.000000
# 75%     700.000000
# max    2000.000000

# %% [markdown]
# ##### percentiles=[]可以控制百分比

# %%
df4.describe(percentiles=[0.04,0.16,0.8])
# Out:
#            游玩时长(h)
# count    15.000000
# mean    520.666667
# std     518.809994
# min      60.000000
# 4%       65.600000
# 16%      90.000000
# 50%     500.000000
# 80%     740.000000
# max    2000.000000

# %% [markdown]
# ##### include='O'时为离散型统计
# 下面结果貌似是在看字符长度（

# %%
df4.describe(include='O')
# Out:
#                         游戏名  游戏平台 Month        年月
# count                    15    15    15        15
# unique                   15     3     9        14
# top     世界计〇彩色舞台 feat. 初音未来  主机游戏    9月  2019年11月
# freq                      1     6     3         2

# %% [markdown]
# ##### include='all'时为全部显示

# %%
df4.describe(include='all')
# Out:
#                         游戏名      游玩时长(h)                 发布时间  游戏平台 Month  \
# count                    15    15.000000                   15    15    15
# unique                   15          NaN                   14     3     9
# top     世界计〇彩色舞台 feat. 初音未来          NaN  2019-11-15 00:00:00  主机游戏    9月
# freq                      1          NaN                    2     6     3
# first                   NaN          NaN  2009-05-05 00:00:00   NaN   NaN
# last                    NaN          NaN  2020-09-20 00:00:00   NaN   NaN
# mean                    NaN   520.666667                  NaN   NaN   NaN
# std                     NaN   518.809994                  NaN   NaN   NaN
# min                     NaN    60.000000                  NaN   NaN   NaN
# 25%                     NaN    95.000000                  NaN   NaN   NaN
# 50%                     NaN   500.000000                  NaN   NaN   NaN
# 75%                     NaN   700.000000                  NaN   NaN   NaN
# ...

# %% [markdown]
# #### 排序
# `df.sort_values(by,axis={0,1},ascending=True,inplace=False, kind={‘quicksort’, ‘mergesort’, ‘heapsort’}, na_position={‘first’, ‘last’})`

# %% [markdown]
# ##### 按发布日期升序

# %%
df4.sort_values(by='发布时间')
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月
# 14               植物大战僵〇    900.0 2009-05-05  PC游戏    5月   2009年5月
# 13            mine〇raft   2000.0 2011-11-18  PC游戏   11月  2011年11月
# 15                魔法〇之夜     90.0 2012-04-12  PC游戏    4月   2012年4月
# 12   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏    9月   2013年9月
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏    6月   2017年6月
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月
# 11          公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏    9月   2018年9月
# 7                  明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月
# ...

# %% [markdown]
# ##### 按发布日期降序

# %%
df4.sort_values(by='发布时间',ascending=False)
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月   2020年9月
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏    3月   2020年3月
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月
# 7                  明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏    9月   2018年9月
# 11          公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏    6月   2017年6月
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月
# 12   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏    9月   2013年9月
# 15                魔法〇之夜     90.0 2012-04-12  PC游戏    4月   2012年4月
# ...

# %% [markdown]
# #### 临时插入重置index
# `df.reset_index(drop={False,True})
# 和各种功能里的ignore_index`

# %%
df4.sort_values(by='发布时间',ascending=False).reset_index()
# Out:
#     index                  游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月
# 0       8  世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月   2020年9月
# 1       4              十〇机兵防卫圈    100.0 2020-03-19  主机游戏    3月   2020年3月
# 2       2                宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月
# 3       3                宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月
# 4       7                 明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月
# 5       5               〇之轨迹IV     70.0 2018-09-27  主机游戏    9月   2018年9月
# 6      11          公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月
# 7       1               马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月
# 8       9                 碧蓝〇线     90.0 2017-06-02  手机游戏    6月   2017年6月
# 9       0           塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月
# 10      6     Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月
# 11     12   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏    9月   2013年9月
# ...

# %%
df4.sort_values(by='发布时间',ascending=False).reset_index(drop=True)
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月
# 0   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月   2020年9月
# 1               十〇机兵防卫圈    100.0 2020-03-19  主机游戏    3月   2020年3月
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月
# 4                  明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏    9月   2018年9月
# 6           公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月
# 7                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月
# 8                  碧蓝〇线     90.0 2017-06-02  手机游戏    6月   2017年6月
# 9            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月
# 10     Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月
# 11   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏    9月   2013年9月
# 12                魔法〇之夜     90.0 2012-04-12  PC游戏    4月   2012年4月
# ...

# %% [markdown]
# #### merge连接
# 类似于SQL里join的功能
# `pd.merge(left,right,how={‘left’, ‘right’, ‘outer’, ‘inner’}, on=None, left_on=None, right_on=None)`

# %% [markdown]
# ##### 先导入新表

# %%
df_me = pd.read_excel('Desktop/test_data_2.xlsx')
df_me
# Out:
#                     游戏名       发行公司
# 0    Grand 〇heft Auto V  Rock 〇tar
# 1             mine〇raft     〇ojang
# 2                植物大战僵〇     Pop〇ap
# 3      Fate/G〇and Order         型〇
# 4                  明日〇舟         鹰〇
# 5   世界计〇彩色舞台 feat. 初音未来       SE〇A
# 6           刀剑〇域黑衣剑士：王牌         恺〇
# 7           公主〇结re:dive    C〇games
# 8            塞〇达传说 旷野之息        任〇堂
# 9                马〇奥赛车8        任〇堂
# 10                宝〇梦·剑      游戏狂〇家
# 11                宝〇梦·盾      游戏狂〇家
# 12              十〇机兵防卫圈        香〇社
# 13               〇之轨迹IV     Fa〇com
# 14                魔法〇之夜         型〇

# %% [markdown]
# ##### 先走一次默认参数看看

# %%
pd.merge(left=df4,right=df_me)
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月       发行公司
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月        任〇堂
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月        任〇堂
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月      游戏狂〇家
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月      游戏狂〇家
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏    3月   2020年3月        香〇社
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏    9月   2018年9月     Fa〇com
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月         型〇
# 7                  明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月         鹰〇
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月   2020年9月       SE〇A
# 9           公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月    C〇games
# 10   Grand 〇heft Auto V    700.0 2013-09-17  PC游戏    9月   2013年9月  Rock 〇tar
# ...

# %% [markdown]
# 碧蓝〇线消失了！how='inner'取的是交集

# %% [markdown]
# ##### how='outer'为两边全都要

# %%
pd.merge(left=df4,right=df_me,how='outer')
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月       发行公司
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月        任〇堂
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月        任〇堂
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月      游戏狂〇家
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月      游戏狂〇家
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏    3月   2020年3月        香〇社
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏    9月   2018年9月     Fa〇com
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月         型〇
# 7                  明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月         鹰〇
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月   2020年9月       SE〇A
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏    6月   2017年6月        NaN
# 10          公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月    C〇games
# ...

# %% [markdown]
# ##### how='right'为以右边的为基准全都要

# %%
pd.merge(left=df4,right=df_me,how='right')
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月       发行公司
# 0    Grand 〇heft Auto V    700.0 2013-09-17  PC游戏    9月   2013年9月  Rock 〇tar
# 1             mine〇raft   2000.0 2011-11-18  PC游戏   11月  2011年11月     〇ojang
# 2                植物大战僵〇    900.0 2009-05-05  PC游戏    5月   2009年5月     Pop〇ap
# 3      Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月         型〇
# 4                  明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月         鹰〇
# 5   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月   2020年9月       SE〇A
# 6           刀剑〇域黑衣剑士：王牌      NaN        NaT   NaN   NaN       NaN         恺〇
# 7           公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月    C〇games
# 8            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月        任〇堂
# 9                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月        任〇堂
# 10                宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月      游戏狂〇家
# ...

# %% [markdown]
# ##### how='left'为以左边的为基准全都要

# %%
df6 = pd.merge(left=df4,right=df_me,how='left')
df6
# Out:
#                     游戏名  游玩时长(h)       发布时间  游戏平台 Month        年月       发行公司
# 0            塞〇达传说 旷野之息    600.0 2017-03-03  主机游戏    3月   2017年3月        任〇堂
# 1                马〇奥赛车8     60.0 2017-12-15  主机游戏   12月  2017年12月        任〇堂
# 2                 宝〇梦·剑    300.0 2019-11-15  主机游戏   11月  2019年11月      游戏狂〇家
# 3                 宝〇梦·盾    700.0 2019-11-15  主机游戏   11月  2019年11月      游戏狂〇家
# 4               十〇机兵防卫圈    100.0 2020-03-19  主机游戏    3月   2020年3月        香〇社
# 5                〇之轨迹IV     70.0 2018-09-27  主机游戏    9月   2018年9月     Fa〇com
# 6      Fate/G〇and Order    900.0 2015-08-12  手机游戏    8月   2015年8月         型〇
# 7                  明日〇舟    500.0 2019-05-01  手机游戏    5月   2019年5月         鹰〇
# 8   世界计〇彩色舞台 feat. 初音未来    100.0 2020-09-20  手机游戏    9月   2020年9月       SE〇A
# 9                  碧蓝〇线     90.0 2017-06-02  手机游戏    6月   2017年6月        NaN
# 10          公主〇结re:dive    700.0 2018-02-15  手机游戏    2月   2018年2月    C〇games
# ...

# %% [markdown]
# ##### 偷偷把碧蓝〇线的发行公司加上
# 这里fillna偷个懒（

# %%
df6.fillna('哔〇哔〇',inplace=True)

# %% [markdown]
# #### Groupby分组
# 我最喜欢的功能之一（
# `df.groupby(by=None,as_index=True)[columns].agg(fun())`

# %%
df6.groupby(by=['游戏平台'])[['游玩时长(h)']].agg([sum,'count','mean',max,min])
# Out:
#      游玩时长(h)
#          sum count   mean     max   min
# 游戏平台
# PC游戏  3690.0     4  922.5  2000.0  90.0
# 主机游戏  1830.0     6  305.0   700.0  60.0
# 手机游戏  2290.0     5  458.0   900.0  90.0

# %%
df6.groupby(by=['游戏平台','发行公司'],as_index=False)['游玩时长(h)'].sum()
# Out:
#     游戏平台       发行公司  游玩时长(h)
# 0   PC游戏     Pop〇ap    900.0
# 1   PC游戏  Rock 〇tar    700.0
# 2   PC游戏     〇ojang   2000.0
# 3   PC游戏         型〇     90.0
# 4   主机游戏     Fa〇com     70.0
# 5   主机游戏        任〇堂    660.0
# 6   主机游戏      游戏狂〇家   1000.0
# 7   主机游戏        香〇社    100.0
# 8   手机游戏    C〇games    700.0
# 9   手机游戏       SE〇A    100.0
# 10  手机游戏       哔〇哔〇     90.0
# 11  手机游戏         型〇    900.0
# 12  手机游戏         鹰〇    500.0

# %%
df6.groupby(by=['发行公司','游戏平台'])[['游玩时长(h)']].count()
# Out:
#                 游玩时长(h)
# 发行公司      游戏平台
# C〇games   手机游戏        1
# Fa〇com    主机游戏        1
# Pop〇ap    PC游戏        1
# Rock 〇tar PC游戏        1
# SE〇A      手机游戏        1
# 〇ojang    PC游戏        1
# 任〇堂       主机游戏        2
# 哔〇哔〇      手机游戏        1
# 型〇        PC游戏        1
#           手机游戏        1
# 游戏狂〇家     主机游戏        2
# 香〇社       主机游戏        1
# 鹰〇        手机游戏        1

# %% [markdown]
# #### pivot_table透视表功能
# `pd.pivot_table(data,values=None, index=None, columns=None, aggfunc='mean', fill_value=None)`

# %%
pd.pivot_table(df6,values='游玩时长(h)',index='发行公司',columns='游戏平台')
# Out:
# 游戏平台         PC游戏   主机游戏   手机游戏
# 发行公司
# C〇games       NaN    NaN  700.0
# Fa〇com        NaN   70.0    NaN
# Pop〇ap      900.0    NaN    NaN
# Rock 〇tar   700.0    NaN    NaN
# SE〇A          NaN    NaN  100.0
# 〇ojang     2000.0    NaN    NaN
# 任〇堂           NaN  330.0    NaN
# 哔〇哔〇          NaN    NaN   90.0
# 型〇           90.0    NaN  900.0
# 游戏狂〇家         NaN  500.0    NaN
# 香〇社           NaN  100.0    NaN
# 鹰〇            NaN    NaN  500.0

# %%
pd.pivot_table(df6,values='游玩时长(h)',index='发行公司',columns='游戏平台',aggfunc=sum, fill_value=0)
# Out:
# 游戏平台       PC游戏  主机游戏  手机游戏
# 发行公司
# C〇games       0     0   700
# Fa〇com        0    70     0
# Pop〇ap      900     0     0
# Rock 〇tar   700     0     0
# SE〇A          0     0   100
# 〇ojang     2000     0     0
# 任〇堂           0   660     0
# 哔〇哔〇          0     0    90
# 型〇           90     0   900
# 游戏狂〇家         0  1000     0
# 香〇社           0   100     0
# 鹰〇            0     0   500

# %% [markdown]
# ## 暂时想不到了，想到再更新~
