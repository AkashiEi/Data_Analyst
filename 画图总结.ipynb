# %% [markdown]
# # 画图总结

# %% [markdown]
# #### 部分代码源自网络

# %% [markdown]
# ## matplotlib 下的 pyplot

# %% [markdown]
# 加载库
# 调整字体
# 显示负号

# %%
from matplotlib import pyplot as plt
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# 导入numpy随机生成些数

# %%
import numpy as np

# %% [markdown]
# 折线图

# %%
plt.plot(np.random.randint(-10,10,15))

plt.title("折线图标题")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")
plt.show()

# %% [markdown]
# 带有标签和图例的多条线的折线图

# %%
plt.plot(np.random.randint(-10,10,3), label='标签A',color = '#39C5BB')
plt.plot(np.random.randint(-10,10,4), label='标签B',color = '#FFA500')
plt.plot(np.random.randint(-10,10,5), label='标签C',color = '#FFE211')
plt.plot(np.random.randint(-10,10,6), label='标签D',color = '#66ccff')

plt.title("带有标签和图例的多条线的折线图")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")

plt.legend()
plt.show()

# %% [markdown]
# 带有标记的折线图

# %%
plt.plot(np.random.randint(-10,10,10),marker='^')

plt.title("带有标记的折线图")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")

plt.show()

# %% [markdown]
# marker大全

# %% [markdown]
# [![7tswdS.png](https://s4.ax1x.com/2022/01/16/7tswdS.png)](https://imgtu.com/i/7tswdS)

# %% [markdown]
# 改变图形的大小

# %%
plt.figure(figsize=(15,5))

plt.plot(np.random.randint(-10,10,10),marker='^')

plt.title("改变图形的大小")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")

plt.show()

# %% [markdown]
# 设置轴限制

# %%
plt.figure(figsize=(15,5))

plt.plot(range(1,21),np.random.randint(-10,10,20))

plt.title("设置轴限制")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")

plt.xlim(10, 20)
plt.ylim(-5, 10)

plt.show()

# %% [markdown]
# 显示背景网格

# %%
plt.figure(figsize=(15,5))

plt.plot(range(1,21),np.random.randint(-10,10,20))

plt.grid(linewidth = 1.2,c='#39C5BB',linestyle = '-.')

plt.title("显示背景网格")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")


plt.show()

# %% [markdown]
# 保存到图像文件

# %%
plt.figure(figsize=(15,5))

plt.plot(range(1,21),np.random.randint(-10,10,20))

plt.grid(linewidth = 1.2,c='#39C5BB',linestyle = '-.')

plt.title("保存到图像文件")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")


plt.savefig('保存到图像文件.png',bbox_inches='tight')

# %% [markdown]
# 图例放在 plot 的不同位置

# %%
plt.figure(figsize=(15,5))

plt.plot(np.random.randint(-10,10,3), label='标签A',color = '#39C5BB')
plt.plot(np.random.randint(-10,10,4), label='标签B',color = '#FFA500')
plt.plot(np.random.randint(-10,10,5), label='标签C',color = '#FFE211')
plt.plot(np.random.randint(-10,10,6), label='标签D',color = '#66ccff')

plt.title("图例放在 plot 的不同位置")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")

plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# 绘制具有不同标记大小的线条

# %%
plt.figure(figsize=(15,5))

plt.plot(np.random.randint(-10,10,3), label='标签A',marker = 'o',ms = 10)
plt.plot(np.random.randint(-10,10,4), label='标签B',marker = 'p',ms = 10)
plt.plot(np.random.randint(-10,10,5), label='标签C',marker = '*',ms = 10)
plt.plot(np.random.randint(-10,10,6), label='标签D',marker = '+',ms = 10)

plt.title("绘制具有不同标记大小的线条")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")

plt.legend()
plt.show()

# %% [markdown]
# 灰度线绘制折线图

# %%
plt.figure(figsize=(15,5))

plt.plot(np.random.randint(-10,10,3), label='标签A',c = '0.1')
plt.plot(np.random.randint(-10,10,4), label='标签B',c = '0.35')
plt.plot(np.random.randint(-10,10,5), label='标签C',c = '0.55')
plt.plot(np.random.randint(-10,10,6), label='标签D',c = '0.4')

plt.title("灰度线绘制折线图")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")

plt.legend()
plt.show()

# %% [markdown]
# 高 dpi 绘制 PDF 输出

# %%
plt.figure(figsize=(15,5))

plt.plot(np.random.randint(-10,10,3), label='标签A',marker = 'o',ms = 10)
plt.plot(np.random.randint(-10,10,4), label='标签B',marker = 'p',ms = 10)
plt.plot(np.random.randint(-10,10,5), label='标签C',marker = '*',ms = 10)
plt.plot(np.random.randint(-10,10,6), label='标签D',marker = '+',ms = 10)

plt.title("高 dpi 绘制 PDF 输出")
plt.xlabel("X轴标题")
plt.ylabel("Y轴标题")

plt.legend()

plt.savefig('高 dpi 绘制 PDF 输出.pdf',dpi = 1200 , format = 'pdf' ,bbox_inches='tight')

# %% [markdown]
# 绘制不同颜色的多线图

# %%
plt.figure(figsize=(15,5))

for i in range(10):
    plt.plot([i]*5, c='C'+str(i), label='Color'+str(i))

plt.xlim(0, 5)

plt.title("绘制不同颜色的多线图")
    
plt.legend()
 
plt.show()

# %% [markdown]
# 语料库创建词云

# %%
import nltk
from nltk.corpus import webtext
from nltk.probability import FreqDist
from wordcloud import WordCloud

plt.figure(figsize=(20,8))

wt_words = webtext.words('君主论.txt',)  # Sample data
data_analysis = nltk.FreqDist(wt_words)

filter_words = dict([(m, n) for m, n in data_analysis.items() if len(m) > 3])

wcloud = WordCloud().generate_from_frequencies(filter_words)

# Plotting the wordcloud
plt.imshow(wcloud, interpolation="bilinear")

plt.title("语料库创建词云")

plt.axis("off")
(-0.5, 399.5, 199.5, -0.5)
plt.show()

# %% [markdown]
# NLTK 词汇色散图

# %%
plt.figure(figsize=(15,5))

wt_words = webtext.words('君主论.txt',)  # Sample data

words = ['Prince', 'King','Princes']

points = [(x, y) for x in range(len(wt_words))
          for y in range(len(words)) if wt_words[x] == words[y]]

if points:
    x, y = zip(*points)
else:
    x = y = ()

plt.plot(x, y, "rx", scalex=.1)
plt.yticks(range(len(words)), words, color="b")
plt.ylim(-1, len(words))
plt.title("NLTK 词汇色散图")
plt.xlabel("字偏移量")
plt.show()

# %% [markdown]
# 字体外观

# %%
plt.figure(figsize=(15,5))

plt.plot(np.random.randint(-10,10,3), label='标签A',marker = 'o',ms = 10)
plt.plot(np.random.randint(-10,10,4), label='标签B',marker = 'p',ms = 10)
plt.plot(np.random.randint(-10,10,5), label='标签C',marker = '*',ms = 10)
plt.plot(np.random.randint(-10,10,6), label='标签D',marker = '+',ms = 10)

font_c = {'size': 16,'weight':'bold','style':'italic'}

plt.title("字体外观",font_c)
plt.xlabel("X轴标题",font_c)
plt.ylabel("Y轴标题",font_c)

plt.legend()
plt.show()

# %% [markdown]
# ### 未完待续~
